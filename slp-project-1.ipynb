# %%
import pandas as pd

import numpy as np

import sklearn

import matplotlib.pyplot as plt

# %%
import tensorflow as tf

import librosa

import os

import soundfile as sf

import torch, torchaudio

import torchaudio.functional as f

import re

from scipy.signal import resample

from sklearn.metrics import accuracy_score

# %%
# Loading Dataset

# %%
dir='/kaggle/input/speech-accent-archive/recordings/recordings'

audio_list = os.listdir(dir)

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ## Extracting MFCC

# %%
target_sample_rate = 44100



def extract_features(audio_file, n_fft=128, hop_length=32, n_mfcc=13):

    y, sr = sf.read(audio_file)



    # Check if sample rate is the same

    if sr != target_sample_rate:

        y = resample(y, int(len(y) * target_sample_rate / sr))

        sr = target_sample_rate



    # Extract first 10 seconds of audio

    samples_10_sec = target_sample_rate * 5

    y_10_sec = y[:samples_10_sec]



    # Extract MFCC

    mfccs = librosa.feature.mfcc(y = y_10_sec, sr=sr, n_mfcc=n_mfcc)



    # Normalize MFCCs

    mfccs_normalized = (mfccs - np.mean(mfccs)) / np.std(mfccs)



    return mfccs

# %%
data = []

for audio in audio_list:

    audio_path = dir + "/" + audio



    feature = extract_features(audio_path)

    label = re.sub(r'\d+', '', audio[:-4])



    data.append((feature, label))

# %% [markdown]
# ## Converting to DataFrame

# %%
seperated_data =[]

label_arr = []

for f,l in data:

    mfcc_dict = {f'MFCC_{i+1}': np.mean(f[i]) for i in range(f.shape[0])}

    label_arr.append(l)

    seperated_data.append(mfcc_dict)

# %%
df_new = pd.DataFrame(seperated_data)

df_new['label'] = label_arr

df_new.head()
# Out:
#        MFCC_1      MFCC_2     MFCC_3     MFCC_4     MFCC_5     MFCC_6  \
# 0 -396.429650  166.844056 -26.592988  19.675905   9.440444 -15.084824
# 1 -315.374044  142.936627 -65.129223   5.381406   7.206723 -10.902184
# 2 -312.487482  125.400791  16.526782  34.864688   4.974225  20.645630
# 3 -352.076937   93.506333 -14.929739  15.153140 -12.022427   2.648440
# 4 -374.195575  104.946241   5.720582  33.258716   3.137331  12.003813
#
#       MFCC_7     MFCC_8     MFCC_9    MFCC_10    MFCC_11   MFCC_12   MFCC_13  \
# 0  12.037416  -6.700806  -6.122482   3.113079 -12.255310 -0.133417 -1.442457
# 1   3.717204 -26.519754  -1.514703  15.668458 -14.213459 -2.694849 -2.021795
# 2  -0.804459   8.526824 -12.421622  -2.128536  -2.235220  2.025745 -0.397765
# 3  -8.378778   3.260275 -23.195564   0.136694  -7.167136 -1.318334  0.569017
# 4  -2.735049   8.224015  -2.002304   1.043862  -1.255645 -3.336594 -3.344836
#
#      label
# 0  spanish
# 1  english
# 2   arabic
# 3  russian
# 4    dutch

# %%
df_new.isnull().sum()
# Out:
# MFCC_1     0
# MFCC_2     0
# MFCC_3     0
# MFCC_4     0
# MFCC_5     0
# MFCC_6     0
# MFCC_7     0
# MFCC_8     0
# MFCC_9     0
# MFCC_10    0
# MFCC_11    0
# MFCC_12    0
# MFCC_13    0
# label      0
# dtype: int64

# %%
print(len(df_new))

df_cleaned = df_new.dropna()

print(len(df_cleaned))
# Out:
# 2138
# 2138

# %%
accent_counts = df_cleaned['label'].value_counts()

print(accent_counts)
# Out:
# label
# english        579
# spanish        162
# arabic         102
# mandarin        65
# french          63
#               ...
# baga             1
# naxi             1
# lamaholot        1
# nama             1
# mortlockese      1
# Name: count, Length: 200, dtype: int64

# %% [markdown]
# ## Oversampling Dataset

# %%
largest_accent = accent_counts.idxmax()

max_count = accent_counts.max()



# Oversample smaller accent groups to match the size of the largest group but take the ones with more than 30 audio files

oversampled_data = []

for accent, count in accent_counts.items():

    if accent != largest_accent and count > 30:

        accent_data = df_cleaned[df_cleaned['label'] == accent]

        oversampled_accent = accent_data.sample(n=max_count, replace=True, random_state=42)

        oversampled_data.append(oversampled_accent)

    elif accent == largest_accent:

        oversampled_data.append(df_cleaned[df_cleaned['label'] == accent])





balanced_df = pd.concat(oversampled_data)

# %%
# handle undersampling kl native / non native

# native = df_cleaned[df_cleaned['label'] == 'native']

# oversampled_native = native.sample(n=1559, replace=True, random_state=42)

# smallest = df_cleaned[df_cleaned['label'] == 'non-native']



# df_balanced = pd.concat([oversampled_native[:len(smallest)], smallest]).reset_index(drop=True)

# df_balanced.head()

# %%
# handle undersampling kl bbrp accent doang

# biggest = df_cleaned[df_cleaned['label'] == 'english']



# spanish = df_cleaned[df_cleaned['label'] == 'spanish']

# oversampled_spanish = spanish.sample(n=579, replace=True, random_state=42)

# arabic = df_cleaned[df_cleaned['label'] == 'arabic']

# oversampled_arabic = arabic.sample(n=579, replace=True, random_state=42)



# df_balanced = pd.concat([biggest, oversampled_spanish, oversampled_arabic]).reset_index(drop=True)

# print(Counter(df_balanced['label']))

# df_balanced.head()

# %%
df_shuffled = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

df_shuffled.head()
# Out:
#        MFCC_1      MFCC_2     MFCC_3     MFCC_4     MFCC_5     MFCC_6  \
# 0 -330.133270  162.584548 -21.769244  -5.104358 -10.122103  -3.721666
# 1 -341.789532  132.619574   0.601831  47.681482   9.711360  -0.294174
# 2 -421.250658   95.664571 -14.816503  18.264395 -11.243732  12.782665
# 3 -319.118536   93.952870  12.912545  49.877915  -4.416125  12.896248
# 4 -358.332221  122.910272   7.424896  32.483800  -1.138527  10.564397
#
#       MFCC_7     MFCC_8     MFCC_9    MFCC_10    MFCC_11    MFCC_12  \
# 0   9.591475 -26.680993 -13.058319  -0.143801 -15.624143   2.044865
# 1  -7.281345 -13.446461 -19.497527 -19.740662  -3.158329  -7.271355
# 2 -21.186349   2.590755  -4.938478 -15.970697 -11.245938 -10.957044
# 3 -19.733087 -10.902267  -8.214854  -1.831642 -19.086026 -11.696086
# 4  -3.145841   8.001234  -4.130050   8.179388  -0.898651   0.960461
#
#      MFCC_13    label
# 0   1.791991   german
# 1  -6.388170   arabic
# 2 -12.194119   korean
# 3  -7.329425  turkish
# 4  -2.046598  russian

# %%
# Seperating Data to x and y

y = df_shuffled["label"]

x = df_shuffled.drop('label', axis = 1)

# %% [markdown]
# ## Encoding Label (From Categorial to Numerical)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

encoded_labels = label_encoder.fit_transform(y)



label_mapping = {label: encoded_label for label, encoded_label in zip(y, encoded_labels)}



# Print the mapping

class_label = []

print("Label mapping:")

for label, encoded_label in label_mapping.items():

    class_label.append(label)

    print(f"{label}: {encoded_label}")
# Out:
# Label mapping:
# german: 4
# arabic: 0
# korean: 6
# turkish: 12
# russian: 10
# portuguese: 9
# english: 2
# mandarin: 7
# dutch: 1
# spanish: 11
# polish: 8
# french: 3
# italian: 5

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Training with Machine Learning Model

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn.fit(x_train, y_train)

knn_pred = knn.predict(x_test)

knn_accuracy = knn.score(x_test, y_test)

knn_accuracy
# Out:
# 0.897078353253652

# %%
y_train_pred_knn = knn.predict(x_train)

train_accuracy_knn = accuracy_score(y_train, y_train_pred_knn)

test_accuracy_knn = accuracy_score(y_test, knn_pred)



print("Training Accuracy: ", train_accuracy_knn)

print("Testing Accuracy: ", test_accuracy_knn)
# Out:
# Training Accuracy:  0.9250954990865304
# Testing Accuracy:  0.897078353253652

# %%
accuracies = [train_accuracy_knn, test_accuracy_knn]



plt.figure(figsize=(8, 4))

plt.bar(['Training Accuracy', 'Testing Accuracy'], accuracies, color=['blue', 'green'])

plt.ylabel('Accuracy')

plt.title('Comparison of Training and Testing Accuracies in KNN Model')

plt.ylim([0, 1])

plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state = 42)

dt.fit(x_train, y_train)

pred_dt = dt.predict(x_test)

dt_accuracy = dt.score(x_test, y_test)

dt_accuracy
# Out:
# 0.9581673306772909

# %%
y_train_pred_dt = dt.predict(x_train)

train_accuracy_dt = accuracy_score(y_train, y_train_pred_dt)

test_accuracy_dt = accuracy_score(y_test, pred_dt)



print("Training Accuracy: ", train_accuracy_dt)

print("Testing Accuracy: ", test_accuracy_dt)
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9581673306772909

# %%
accuracies = [train_accuracy_dt, test_accuracy_dt]



plt.figure(figsize=(8, 4))

plt.bar(['Training Accuracy', 'Testing Accuracy'], accuracies, color=['blue', 'green'])

plt.ylabel('Accuracy')

plt.title('Comparison of Training and Testing Accuracies in Decision Tree Model')

plt.ylim([0, 1])

plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

randf = RandomForestClassifier(random_state = 42)

randf.fit(x_train, y_train)

pred_randf = randf.predict(x_test)

randf_accuracy = randf.score(x_test, y_test)

randf_accuracy
# Out:
# 0.9873837981407703

# %%
y_train_pred_rf = randf.predict(x_train)

train_accuracy_rf = accuracy_score(y_train, y_train_pred_rf)

test_accuracy_rf = accuracy_score(y_test, pred_randf)



print("Training Accuracy: ", train_accuracy_rf)

print("Testing Accuracy: ", test_accuracy_rf)
# Out:
# Training Accuracy:  1.0
# Testing Accuracy:  0.9873837981407703

# %%
accuracies = [train_accuracy_rf, test_accuracy_rf]



plt.figure(figsize=(8, 4))

plt.bar(['Training Accuracy', 'Testing Accuracy'], accuracies, color=['blue', 'green'])

plt.ylabel('Accuracy')

plt.title('Comparison of Training and Testing Accuracies in Random Forest Model')

plt.ylim([0, 1])

plt.show()

# %%
import joblib as jb

# save models

jb.dump(knn, 'knn_model_5.joblib')

jb.dump(dt, 'dt_model_5.joblib')

jb.dump(randf, 'randf_model_5.joblib')
# Out:
# ['randf_model_5.joblib']

# %%
# # load models

# knn_default = jb.load('knn.joblib')

# dt_default = jb.load('dt.joblib')

# randf_default = jb.load('randf.joblib')

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#       arabic       0.87      0.93      0.90       141
#        dutch       0.87      1.00      0.93       119
#      english       0.55      0.06      0.10       107
#       french       0.91      0.97      0.94       107
#       german       0.94      1.00      0.97       114
#      italian       0.94      1.00      0.97       119
#       korean       0.87      0.98      0.92       111
#     mandarin       0.93      0.94      0.94       124
#       polish       0.92      1.00      0.96       109
#   portuguese       0.92      1.00      0.96       104
#      russian       0.87      1.00      0.93       110
#      spanish       0.81      0.74      0.78       124
#      turkish       0.94      1.00      0.97       117
#
#     accuracy                           0.90      1506
#    macro avg       0.87      0.89      0.87      1506
# weighted avg       0.87      0.90      0.87      1506

# %%
print(classification_report(y_test, pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#       arabic       0.97      1.00      0.98       141
#        dutch       1.00      1.00      1.00       119
#      english       0.96      0.46      0.62       107
#       french       0.93      0.99      0.96       107
#       german       0.97      1.00      0.98       114
#      italian       0.99      1.00      1.00       119
#       korean       0.98      1.00      0.99       111
#     mandarin       0.95      1.00      0.98       124
#       polish       0.96      1.00      0.98       109
#   portuguese       0.95      1.00      0.98       104
#      russian       0.94      1.00      0.97       110
#      spanish       0.89      0.97      0.93       124
#      turkish       0.97      1.00      0.98       117
#
#     accuracy                           0.96      1506
#    macro avg       0.96      0.96      0.95      1506
# weighted avg       0.96      0.96      0.95      1506

# %%
print(classification_report(y_test, pred_randf))
# Out:
#               precision    recall  f1-score   support
#
#       arabic       0.97      1.00      0.99       141
#        dutch       1.00      1.00      1.00       119
#      english       0.95      0.87      0.91       107
#       french       1.00      0.99      1.00       107
#       german       1.00      1.00      1.00       114
#      italian       1.00      1.00      1.00       119
#       korean       0.99      1.00      1.00       111
#     mandarin       0.98      1.00      0.99       124
#       polish       0.99      1.00      1.00       109
#   portuguese       1.00      1.00      1.00       104
#      russian       1.00      1.00      1.00       110
#      spanish       0.96      0.97      0.96       124
#      turkish       0.99      1.00      1.00       117
#
#     accuracy                           0.99      1506
#    macro avg       0.99      0.99      0.99      1506
# weighted avg       0.99      0.99      0.99      1506

# %% [markdown]
# # CNN

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.utils import to_categorical

# %%
X = np.array(df_shuffled.drop('label', axis=1).values)

y = df_shuffled['label'].values

# %%
label_encoder = LabelEncoder()

y_encoded = label_encoder.fit_transform(y)



y_onehot = to_categorical(y_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42)

# %%
# X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)

# X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D



def build_cnn_model(input_shape):

    model = Sequential()

    model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape))

    model.add(MaxPooling1D(pool_size=2))

    model.add(Conv1D(64, 3, activation='relu'))

    model.add(MaxPooling1D(2))

    model.add(Flatten())

    model.add(Dense(128, activation='relu'))

    model.add(Dropout(0.5))

    model.add(Dense(y_train.shape[1], activation='softmax'))



    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

    return model



input_shape = (X_train.shape[1], 1)



model = build_cnn_model(input_shape)

history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730964888.326676     102 service.cc:145] XLA service 0x7a8040004f60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730964888.326727     102 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1730964888.326731     102 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1730964891.818673     102 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 189/189 - 8s - 42ms/step - accuracy: 0.1040 - loss: 3.5254 - val_accuracy: 0.1434 - val_loss: 2.4834
# Epoch 2/150
# 189/189 - 0s - 2ms/step - accuracy: 0.1463 - loss: 2.4823 - val_accuracy: 0.1799 - val_loss: 2.4456
# Epoch 3/150
# 189/189 - 0s - 2ms/step - accuracy: 0.1533 - loss: 2.4360 - val_accuracy: 0.2032 - val_loss: 2.3388
# Epoch 4/150
# 189/189 - 0s - 2ms/step - accuracy: 0.1649 - loss: 2.4069 - val_accuracy: 0.2112 - val_loss: 2.3307
# Epoch 5/150
# 189/189 - 0s - 2ms/step - accuracy: 0.2061 - loss: 2.3273 - val_accuracy: 0.2809 - val_loss: 2.1981
# Epoch 6/150
# 189/189 - 0s - 2ms/step - accuracy: 0.2299 - loss: 2.2479 - val_accuracy: 0.3247 - val_loss: 2.1208
# Epoch 7/150
# 189/189 - 0s - 2ms/step - accuracy: 0.2604 - loss: 2.1832 - val_accuracy: 0.3108 - val_loss: 2.1034
# Epoch 8/150
# 189/189 - 0s - 2ms/step - accuracy: 0.2707 - loss: 2.1245 - val_accuracy: 0.3533 - val_loss: 1.9732
# Epoch 9/150
# 189/189 - 0s - 2ms/step - accuracy: 0.3096 - loss: 2.0384 - val_accuracy: 0.4117 - val_loss: 1.8912
# Epoch 10/150
# 189/189 - 0s - 2ms/step - accuracy: 0.3254 - loss: 1.9650 - val_accuracy: 0.4017 - val_loss: 1.8295
# Epoch 11/150
# 189/189 - 0s - 2ms/step - accuracy: 0.3499 - loss: 1.9198 - val_accuracy: 0.4442 - val_loss: 1.7447
# Epoch 12/150
# 189/189 - 0s - 2ms/step - accuracy: 0.3667 - loss: 1.8529 - val_accuracy: 0.4741 - val_loss: 1.6314
# Epoch 13/150
# 189/189 - 0s - 2ms/step - accuracy: 0.3876 - loss: 1.7975 - val_accuracy: 0.4847 - val_loss: 1.5633
# Epoch 14/150
# 189/189 - 0s - 2ms/step - accuracy: 0.4066 - loss: 1.7255 - val_accuracy: 0.5558 - val_loss: 1.4804
# Epoch 15/150
# 189/189 - 0s - 2ms/step - accuracy: 0.4336 - loss: 1.6542 - val_accuracy: 0.5564 - val_loss: 1.4401
# Epoch 16/150
# 189/189 - 0s - 2ms/step - accuracy: 0.4519 - loss: 1.6064 - val_accuracy: 0.5950 - val_loss: 1.3389
# Epoch 17/150
# 189/189 - 0s - 2ms/step - accuracy: 0.4677 - loss: 1.5421 - val_accuracy: 0.6122 - val_loss: 1.2956
# Epoch 18/150
# 189/189 - 0s - 2ms/step - accuracy: 0.4738 - loss: 1.5125 - val_accuracy: 0.6096 - val_loss: 1.2482
# Epoch 19/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5001 - loss: 1.4746 - val_accuracy: 0.6640 - val_loss: 1.1844
# Epoch 20/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5089 - loss: 1.4012 - val_accuracy: 0.6594 - val_loss: 1.1173
# Epoch 21/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5220 - loss: 1.3674 - val_accuracy: 0.6753 - val_loss: 1.0976
# Epoch 22/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5300 - loss: 1.3388 - val_accuracy: 0.6760 - val_loss: 1.0578
# Epoch 23/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5325 - loss: 1.3430 - val_accuracy: 0.7012 - val_loss: 1.0382
# Epoch 24/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5502 - loss: 1.2902 - val_accuracy: 0.6892 - val_loss: 1.0239
# Epoch 25/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5464 - loss: 1.2772 - val_accuracy: 0.6926 - val_loss: 0.9956
# Epoch 26/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5629 - loss: 1.2419 - val_accuracy: 0.7185 - val_loss: 0.9251
# Epoch 27/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5796 - loss: 1.1944 - val_accuracy: 0.7238 - val_loss: 0.8750
# Epoch 28/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5757 - loss: 1.1954 - val_accuracy: 0.7556 - val_loss: 0.8329
# Epoch 29/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5931 - loss: 1.1440 - val_accuracy: 0.7317 - val_loss: 0.8508
# Epoch 30/150
# 189/189 - 0s - 2ms/step - accuracy: 0.6007 - loss: 1.1324 - val_accuracy: 0.7696 - val_loss: 0.8272
# Epoch 31/150
# 189/189 - 0s - 2ms/step - accuracy: 0.6034 - loss: 1.1179 - val_accuracy: 0.7815 - val_loss: 0.7999
# Epoch 32/150
# 189/189 - 0s - 2ms/step - accuracy: 0.6148 - loss: 1.0906 - val_accuracy: 0.7776 - val_loss: 0.7543
# Epoch 33/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5919 - loss: 1.1380 - val_accuracy: 0.7776 - val_loss: 0.7391
# Epoch 34/150
# 189/189 - 0s - 2ms/step - accuracy: 0.6192 - loss: 1.0760 - val_accuracy: 0.8001 - val_loss: 0.7169
# Epoch 35/150
# 189/189 - 0s - 2ms/step - accuracy: 0.6210 - loss: 1.0604 - val_accuracy: 0.8021 - val_loss: 0.6860
# Epoch 36/150
# 189/189 - 0s - 2ms/step - accuracy: 0.6293 - loss: 1.0531 - val_accuracy: 0.8101 - val_loss: 0.6976
# Epoch 37/150
# 189/189 - 0s - 2ms/step - accuracy: 0.6378 - loss: 1.0124 - val_accuracy: 0.8181 - val_loss: 0.6455
# Epoch 38/150
# 189/189 - 0s - 2ms/step - accuracy: 0.6418 - loss: 1.0128 - val_accuracy: 0.8207 - val_loss: 0.6582
# Epoch 39/150
150
# 189/189 - 1s - 3ms/step - accuracy: 0.8168 - loss: 0.5066 - val_accuracy: 0.9422 - val_loss: 0.2336
# Epoch 149/150
# 189/189 - 0s - 2ms/step - accuracy: 0.8009 - loss: 0.5624 - val_accuracy: 0.9223 - val_loss: 0.2574
# Epoch 150/150
# 189/189 - 0s - 2ms/step - accuracy: 0.8218 - loss: 0.5002 - val_accuracy: 0.9256 - val_loss: 0.2476

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print(f"Test Loss: {loss}")

print(f"Test Accuracy: {accuracy}")
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9106 - loss: 0.2827
# Test Loss: 0.2476133108139038
# Test Accuracy: 0.9256308078765869

# %% [markdown]
# ## Plotting Accuracy & Loss of CNN Before Hyperparameter Tuned

# %%
metrics = history.history



plt.figure(figsize=(10,8))

plt.plot(history.epoch, 100 * np.array(metrics['accuracy']), 100 * np.array(metrics['val_accuracy']))

plt.title("Accuracy CNN")

plt.ylim([0,100])

plt.xlabel("Epochs")

plt.ylabel("Accuracy")

plt.legend(['accuracy', 'val_accuracy'])

plt.show()

# %%
plt.figure(figsize=(10,8))

plt.plot(history.epoch, np.array(metrics['loss']), np.array(metrics['val_loss']))

plt.title("Loss CNN")

plt.xlabel("Epochs")

plt.ylabel("Loss")

plt.legend(['loss', 'val_loss'])

plt.show()

# %%
import numpy as np



y_pred_probs = model.predict(X_test)

y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
y_true = np.argmax(y_test, axis=1)

# %%
from sklearn.metrics import classification_report



class_names = [

    "Arabic", "Dutch", "English", "French", "German",

    "Italian", "Korean", "Mandarin", "Polish", "Portuguese",

    "Russian", "Spanish", "Turkish"

]



report = classification_report(y_true, y_pred, target_names=class_names)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Arabic       0.91      0.93      0.92       141
#        Dutch       0.96      1.00      0.98       119
#      English       0.66      0.61      0.63       107
#       French       0.96      0.95      0.96       107
#       German       0.97      0.99      0.98       114
#      Italian       1.00      0.94      0.97       119
#       Korean       0.93      0.98      0.96       111
#     Mandarin       0.97      0.91      0.94       124
#       Polish       0.97      1.00      0.99       109
#   Portuguese       0.99      0.98      0.99       104
#      Russian       0.86      1.00      0.92       110
#      Spanish       0.83      0.77      0.79       124
#      Turkish       1.00      0.97      0.99       117
#
#     accuracy                           0.93      1506
#    macro avg       0.92      0.93      0.92      1506
# weighted avg       0.92      0.93      0.92      1506

# %%
model.save('cnn.h5')

# %%
from tensorflow.keras.models import load_model



model = load_model('cnn.h5')

# %%
model.save('cnn_model.keras')  # TensorFlow will use the SavedModel format by default

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

from tensorflow.keras.models import Sequential

from tensorflow.keras.optimizers import Adam

from kerastuner import HyperModel



class CNNHyperModel(HyperModel):

    def __init__(self, input_shape, num_classes):

        self.input_shape = input_shape

        self.num_classes = num_classes



    def build(self, hp):

        model = Sequential()

        model.add(Conv1D(

            filters=hp.Int('filters1', min_value=32, max_value=128, step=32),

            kernel_size=hp.Int('kernel_size1', min_value=2, max_value=5, step=1),

            activation='relu',

            padding='same',

            input_shape=self.input_shape

        ))

        model.add(MaxPooling1D(pool_size=2))

        model.add(Conv1D(

            filters=hp.Int('filters2', min_value=64, max_value=256, step=32),

            kernel_size=hp.Int('kernel_size2', min_value=2, max_value=5, step=1),

            activation='relu',

            padding='same'

        ))

        model.add(MaxPooling1D(pool_size=2))

        model.add(Flatten())

        model.add(Dense(

            hp.Int('dense_units', min_value=64, max_value=256, step=64),

            activation='relu'

        ))

        model.add(Dropout(hp.Float('dropout_rate', min_value=0.2, max_value=0.5, step=0.1)))

        model.add(Dense(self.num_classes, activation='softmax'))



        model.compile(

            optimizer=Adam(

                hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')

            ),

            loss='categorical_crossentropy',

            metrics=['accuracy']

        )

        return model
# Out:
# /tmp/ipykernel_30/904362695.py:7: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner import HyperModel

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau



early_stopper = EarlyStopping(

    monitor='val_loss',

    patience=10,

    verbose=1,

    restore_best_weights=True

)

reduce_lr = ReduceLROnPlateau(

    monitor='val_loss',

    factor=0.5,

    patience=5,

    verbose=1,

    min_lr=1e-6

)

# %%
from kerastuner.tuners import RandomSearch



input_shape = (X_train.shape[1], 1)

num_classes = y_train.shape[1]



hypermodel = CNNHyperModel(input_shape=input_shape, num_classes=num_classes)



tuner = RandomSearch(

    hypermodel,

    objective='val_accuracy',

    max_trials=20,

    executions_per_trial=2,

    directory='model_tuning',

    project_name='AccentClassification'

)



tuner.search(x=X_train, y=y_train, epochs=50, validation_data=(X_test, y_test), callbacks=[early_stopper, reduce_lr])
# Out:
# Trial 20 Complete [00h 00m 58s]
# val_accuracy: 0.9681274890899658
#
# Best val_accuracy So Far: 0.9784196615219116
# Total elapsed time: 00h 13m 41s

# %%
best_model = tuner.get_best_models(num_models=1)[0]

loss, accuracy = best_model.evaluate(X_test, y_test)

print("Best model accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:415: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 18 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9756 - loss: 0.1407
# Best model accuracy: 97.94%

# %%
# Creating CNN model with the optimized parameter from the start

def create_cnn_model(input_shape, num_classes):

    model = Sequential()



    model.add(Conv1D(filters=32, kernel_size=4, activation='relu', padding='same', input_shape=input_shape))

    model.add(MaxPooling1D(pool_size=2))



    model.add(Conv1D(filters=128, kernel_size=3, activation='relu', padding='same'))

    model.add(MaxPooling1D(pool_size=2))



    model.add(Flatten())



    model.add(Dense(256, activation='relu'))



    model.add(Dropout(0.2))



    model.add(Dense(num_classes, activation='softmax'))



    model.compile(optimizer=Adam(learning_rate=0.0011876), loss='categorical_crossentropy', metrics=['accuracy'])



    return model



best_model = create_cnn_model(input_shape, num_classes)



# Train data again from the start

history = best_model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/150
# 189/189 - 6s - 34ms/step - accuracy: 0.1382 - loss: 3.1160 - val_accuracy: 0.2244 - val_loss: 2.3912
# Epoch 2/150
# 189/189 - 0s - 2ms/step - accuracy: 0.2184 - loss: 2.3416 - val_accuracy: 0.2576 - val_loss: 2.1837
# Epoch 3/150
# 189/189 - 0s - 2ms/step - accuracy: 0.3139 - loss: 2.0934 - val_accuracy: 0.4104 - val_loss: 1.8784
# Epoch 4/150
# 189/189 - 0s - 2ms/step - accuracy: 0.4516 - loss: 1.6931 - val_accuracy: 0.5684 - val_loss: 1.4086
# Epoch 5/150
# 189/189 - 0s - 2ms/step - accuracy: 0.5981 - loss: 1.2663 - val_accuracy: 0.6906 - val_loss: 1.0192
# Epoch 6/150
# 189/189 - 0s - 2ms/step - accuracy: 0.
150
# 189/189 - 0s - 2ms/step - accuracy: 0.9942 - loss: 0.0179 - val_accuracy: 0.9701 - val_loss: 0.2662
# Epoch 129/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9829 - loss: 0.0802 - val_accuracy: 0.9575 - val_loss: 0.4040
# Epoch 130/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9814 - loss: 0.0811 - val_accuracy: 0.9522 - val_loss: 0.4038
# Epoch 131/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9794 - loss: 0.0776 - val_accuracy: 0.9701 - val_loss: 0.2873
# Epoch 132/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9917 - loss: 0.0283 - val_accuracy: 0.9701 - val_loss: 0.2432
# Epoch 133/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9935 - loss: 0.0198 - val_accuracy: 0.9714 - val_loss: 0.2742
# Epoch 134/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9925 - loss: 0.0227 - val_accuracy: 0.9708 - val_loss: 0.2573
# Epoch 135/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9851 - loss: 0.0515 - val_accuracy: 0.9661 - val_loss: 0.2847
# Epoch 136/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9887 - loss: 0.0419 - val_accuracy: 0.9641 - val_loss: 0.3017
# Epoch 137/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9909 - loss: 0.0304 - val_accuracy: 0.9675 - val_loss: 0.3122
# Epoch 138/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9819 - loss: 0.0694 - val_accuracy: 0.9681 - val_loss: 0.2662
# Epoch 139/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9875 - loss: 0.0517 - val_accuracy: 0.9661 - val_loss: 0.3392
# Epoch 140/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9934 - loss: 0.0234 - val_accuracy: 0.9708 - val_loss: 0.2918
# Epoch 141/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9912 - loss: 0.0297 - val_accuracy: 0.9781 - val_loss: 0.2249
# Epoch 142/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9932 - loss: 0.0254 - val_accuracy: 0.9721 - val_loss: 0.2333
# Epoch 143/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9957 - loss: 0.0155 - val_accuracy: 0.9761 - val_loss: 0.2304
# Epoch 144/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9942 - loss: 0.0180 - val_accuracy: 0.9661 - val_loss: 0.3407
# Epoch 145/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9862 - loss: 0.0638 - val_accuracy: 0.9695 - val_loss: 0.3107
# Epoch 146/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9887 - loss: 0.0422 - val_accuracy: 0.9721 - val_loss: 0.2655
# Epoch 147/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9895 - loss: 0.0407 - val_accuracy: 0.9668 - val_loss: 0.3524
# Epoch 148/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9917 - loss: 0.0272 - val_accuracy: 0.9714 - val_loss: 0.2682
# Epoch 149/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9925 - loss: 0.0244 - val_accuracy: 0.9675 - val_loss: 0.3629
# Epoch 150/150
# 189/189 - 0s - 2ms/step - accuracy: 0.9934 - loss: 0.0231 - val_accuracy: 0.9734 - val_loss: 0.2538

# %% [markdown]
# ## Plotting Accuracy & Loss CNN After Hyperparameter Tuned

# %%
metrics = history.history



plt.figure(figsize=(10,8))

plt.plot(history.epoch, 100 * np.array(metrics['accuracy']), 100 * np.array(metrics['val_accuracy']))

plt.title("Accuracy CNN Hyperparameter Tuned")

plt.ylim([0,100])

plt.xlabel("Epochs")

plt.ylabel("Accuracy")

plt.legend(['accuracy', 'val_accuracy'])

plt.show()

# %%
plt.figure(figsize=(10,8))

plt.plot(history.epoch, np.array(metrics['loss']), np.array(metrics['val_loss']))

plt.title("Loss CNN Hyperparameter Tuned")

plt.xlabel("Epochs")

plt.ylabel("Loss")

plt.legend(['loss', 'val_loss'])

plt.show()

# %%
import numpy as np



# Predict the probabilities for each class

y_pred_probs = best_model.predict(X_test)

# Convert probabilities to class labels

y_pred = np.argmax(y_pred_probs, axis=1)

y_true = np.argmax(y_test, axis=1)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from sklearn.metrics import classification_report



class_names = [

    "Arabic", "Dutch", "English", "French", "German",

    "Italian", "Korean", "Mandarin", "Polish", "Portuguese",

    "Russian", "Spanish", "Turkish"

]



report = classification_report(y_true, y_pred, target_names=class_names)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       Arabic       0.97      1.00      0.98       141
#        Dutch       0.99      1.00      1.00       119
#      English       0.96      0.66      0.78       107
#       French       0.97      0.99      0.98       107
#       German       1.00      1.00      1.00       114
#      Italian       0.98      1.00      0.99       119
#       Korean       0.97      1.00      0.99       111
#     Mandarin       0.97      1.00      0.98       124
#       Polish       1.00      1.00      1.00       109
#   Portuguese       0.96      1.00      0.98       104
#      Russian       0.99      1.00      1.00       110
#      Spanish       0.91      0.98      0.94       124
#      Turkish       0.98      1.00      0.99       117
#
#     accuracy                           0.97      1506
#    macro avg       0.97      0.97      0.97      1506
# weighted avg       0.97      0.97      0.97      1506

# %%
# Save the model

best_model.save('cnn_tunning.h5')

loaded_model = load_model('cnn_tunning.h5')

loss, accuracy = loaded_model.evaluate(X_test, y_test)

print("Loaded model accuracy:", accuracy)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9734 - loss: 0.2738
# Loaded model accuracy: 0.9734395742416382

# %%
best_model.save('cnn_tunning_keras.keras')

# %%
from tensorflow.keras.models import load_model



# Load the best model you saved earlier

model = load_model('/kaggle/working/cnn_tunning.h5')

# %%
def preprocess_audio(file_path, target_sample_rate=44100, n_mfcc=13):

    # Load data

    y, sr = librosa.load(file_path, sr=target_sample_rate)



    # Extract MFCC

    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)



    # Normalize MFCC

    mfcc = (mfcc - np.mean(mfcc)) / np.std(mfcc)

    mfcc = mfcc.T



    # Get 13 MFCC coefficients

    if mfcc.shape[0] > 13:

        mfcc = mfcc[:13, :]

    else:

        # Padd with zeros if coefficients are less than 13

        mfcc = np.pad(mfcc, ((0, 13 - mfcc.shape[0]), (0, 0)), mode='constant')

    mfcc = np.mean(mfcc, axis=1, keepdims=True)



    # Expand dimensions to match the input shape of the model (batch_size, time_steps, features)

    mfcc = np.expand_dims(mfcc, axis=0)



    return mfcc

# %%
file_path = '/kaggle/input/speech-accent-archive/recordings/recordings/english113.mp3'

# Preprocess the audio

audio_data = preprocess_audio(file_path)

print("Shape of preprocessed audio data:", audio_data.shape)
# Out:
# Shape of preprocessed audio data: (1, 13, 1)

# %%
predictions = model.predict(audio_data)


predicted_class = np.argmax(predictions, axis=1)



class_names = [

    "Arabic", "Dutch", "English", "French", "German",

    "Italian", "Korean", "Mandarin", "Polish", "Portuguese",

    "Russian", "Spanish", "Turkish"

]



print(f"The predicted class for the audio file is: {class_names[predicted_class[0]]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for the audio file is: English

# %%
model.save('cnn_tunning.h5')

# %%
import tensorflow as tf

from joblib import load



def load_model(model_name):

    if model_name.endswith('.h5'):

        model = tf.keras.models.load_model(model_name)

    else:

        model = load(f'{model_name}.joblib')

    return model



load_model('/kaggle/working/cnn_tunning.h5')
# Out:
# <Sequential name=sequential_1, built=True>
